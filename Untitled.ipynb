# %%
section = A
if section == "A":
    if roll == 101:
        if subject == "Python":
            print("Python student")
        elif
        else

# %%
for i in range(1,6):
    print(i)
    i += 2
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
i = 0 
while i<=6:
    i += 2
    print(i)
# Out:
# 2
# 4
# 6
# 8
