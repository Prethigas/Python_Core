# %% [raw]
# Exception handling :
# Exception handling is a way to deal with errors that happen while your program is running, so that instead of crashing completely, your program can respond gracefully — print a helpful message, retry, use a fallback value, or clean up resources — and then continue (or exit in a controlled way).

# %% [raw]
# Keyword	  What it does
# try	      Contains the code that might raise an error
# except	  Runs if an error occurs in try — you can catch specific error types(ValueError, ZeroDivisionError, etc.) or use Exception to catch                     anything
# else	  Runs only if try succeeds with no error
# finally	  Always runs, whether there was an error or not — used for cleanup
# raise	  Lets you manually trigger an error, including custom ones you define
# as e      Captures the exception object so you can inspect its message
# Multiple  Let you handle different error types differently, checked top-to-
# except    bottom
# blocks

# %% [raw]
# An exception is just Python's way of saying "something went wrong."
# ValueError — invalid value (e.g., int("abc"))
# TypeError — wrong data type used in an operation (e.g., "1" + 1)
# ZeroDivisionError — dividing by zero
# NameError — using a variable that doesn't exist
# IndexError — accessing a list index that's out of range

# %%
# a=int("abc")
# print(a)

# %%
try:
    a=int("abc")
except ValueError:
    print("Cann't covert string to int")
# Out:
# Cann't covert string to int

# %%
# b="1"+1
# print(a)

# %%
try: 
    b="1"+1
    print(a)
except TypeError:
    print("cann't do this Operation")
# Out:
# cann't do this Operation

# %%
# c=10/0
# print(c)

# %%
try:
    print(10/0)
except Exception as e:
    print(e)
# Out:
# division by zero

# %%
# print(age)

# %%
try:
    print(age)
except Exception as e:
    print(e)
# Out:
# name 'age' is not defined

# %%
# ageValues = [10, 20, 30, 40]
# print(ageValues[6])

# %%
try:
    ageValues = [10, 20, 30, 40]
    print(ageValues[6])
except Exception as e:
    print(e)
# Out:
# list index out of range

# %%
#Exploring built-in functions/keywords
print(len(dir(locals()['__builtins__'])))
# print(dir(locals()['__builtins__']))
# Out:
# 161

# %%
try:
    age = int(input('Enter your Age : '))
    print(age)
except Exception as e:
    print('Enter Numeric Values Only!....')
    age = int(input('Enter your Age : '))
    print(age)
# Out:
# Enter your Age :  prethi
# Enter Numeric Values Only!....
# Enter your Age :  22
# 22

# %%
#Raising your own exceptions
def set_age(age):
    if age < 0:
        raise ValueError('Age cannot be negative')
    return age

try:
    set_age(-5)
except ValueError as e:
    print(e)

# %%
# Order matters with multiple except blocks try:
    a = int(input('Enter Value 01 : '))
    b = int(input('Enter Value 02 : '))
    print(a / b)
except ValueError as e:
    print('Enter Numeric Only!...', e)
except ZeroDivisionError:
    print('Divisor Cannot be Zero!..')
except Exception as e:
    print(e)
# Out:
# Enter Value 01 :  12
# Enter Value 02 :  2
# 6.0

# %%
try:
    a = 10
    b = 0
    result = a / b
except Exception as err:
    print('Programm have Some Error!...', err)
else: 
    print(result)
finally:
    print('Thank you Come Again!...')
# Out:
# Programm have Some Error!... division by zero
# Thank you Come Again!...
